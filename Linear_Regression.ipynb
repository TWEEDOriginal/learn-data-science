# %% [markdown]
# <a href="https://colab.research.google.com/github/TWEEDOriginal/learn-data-science/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 37.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939417 sha256=4665ede0fc6c36f5b59337c858da46a28bc6bbb351a0e8dc84325a192ebfad1e
#   Stored in directory: /root/.cache/pip/wheels/29/93/3f/af54c413cecaac292940342c61882d2a8848674175d0bb0889
# Successfully built pydataset
# ...

# %%
from  pydataset import data
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
# Out:
# initiated datasets repo at: /root/.pydataset/

# %%
# %matplotlib inline

# %%
pima = data('Pima.tr')
pima
# Out:
#      npreg  glu  bp  skin   bmi    ped  age type
# 1        5   86  68    28  30.2  0.364   24   No
# 2        7  195  70    33  25.1  0.163   55  Yes
# 3        5   77  82    41  35.8  0.156   35   No
# 4        0  165  76    43  47.9  0.259   26   No
# 5        0  107  60    25  26.4  0.133   23   No
# ..     ...  ...  ..   ...   ...    ...  ...  ...
# 196      2  141  58    34  25.4  0.699   24   No
# 197      7  129  68    49  38.5  0.439   43  Yes
# 198      0  106  70    37  39.4  0.605   22   No
# 199      1  118  58    36  33.3  0.261   23   No
# 200      8  155  62    26  34.0  0.543   46  Yes
#
# [200 rows x 8 columns]

# %%
pima.plot(kind = 'scatter', x = 'skin', y = 'bmi')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(pima.skin, pima.bmi)

# %%
plt.scatter(X_train, y_train, label = 'training data')
plt.scatter(X_test, y_test, label = 'testing data')
plt.legend()
plt.title('test train split')
plt.show()

# %%
LR = LinearRegression()
# MUST be 2 dimensional
# convert from scalar 1, to 1,1
LR.fit(X_train.values.reshape(-1,1), y_train.values)
# Out:
# LinearRegression()

# %%
# use model to predict on test data
prediction = LR.predict(X_test.values.reshape(-1,1))

# plot prediction line against test data
plt.plot(X_test, prediction, label = 'LR prediction', color = 'b')
plt.scatter(X_test, y_test, label = 'test data', color = 'g', alpha=.7)
plt.legend()
plt.show()

# %%
# predict bmi of woman with sking fold == 50
LR.predict(np.array([[50]]))[0]
# Out:
# 39.45738608951851

# %%
# score model
LR.score(X_test.values.reshape(-1,1), y_test)
# Out:
# 0.4783037385879235
